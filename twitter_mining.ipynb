# %%
import tweepy
import pandas as pd

# %%
# %run C:\Users\yonyb\keys.ipynb

# %%
client = tweepy.Client(bearer_token=bearer_token)
#the node is the id of the twitter user  (roi mirovsky)
node = client.get_user(username="RoiMirov").data.id

# %%
 = client.get_users_following(id=node)
following.data
# Out:
# [<User id=750751206427860992 name=Marvel Studios username=MarvelStudios>,
#  <User id=15687962 name=Marvel Entertainment username=Marvel>,
#  <User id=710908592 name=Matan Amir username=matan_amirr>,
#  <User id=1481286902930190336 name=חדשות פוליטיות מלפני שנה username=MilifneyShana>,
#  <User id=1103181775730327552 name=קובי אוז username=kobioz1>,
#  <User id=792405214762561537 name=Beitar Jerusalem FC username=fcbeitar>,
#  <User id=3233484298 name=Year Progress username=year_progress>,
#  <User id=2348783658 name=יצחק הרצוג Isaac Herzog username=Isaac_Herzog>,
#  <User id=1091091503865384960 name=עומר בבאי omer babai username=omerbabai>,
#  <User id=1040246229895204865 name=ערוץ כנסת username=KnessetT>,
#  <User id=1428289527186137094 name=Yonatan username=yonsha05>,
#  <User id=3085312765 name=Amir Hetsroni username=AmirHetsroni>,
#  <User id=84180288 name=🫵🏻❤️Yoav Rabinovitz ⁦ username=yoavr>,
#  <User id=247253781 name=Reshef Shay username=Rereshef>,
#  <User id=327746094 name=יבגני זרובינסקי username=ivgiz>,
#  <User id=1273276672570253313 name=yoram lass username=LassYoram>,
#  <User id=37960888 name=Chaim Levinson username=chaimlevinson>,
#  <User id=933990392 name=ינון מגל username=YinonMagal>,
#  <User id=3039661429 name=רינה מצליח username=RMatsliah>,
#  <User id=2426169308 name=Akiva Novick username=akivanovick>,
#  <User id=917451193 name=אריה מכלוף דרעי username=ariyederi>,
#  <User id=949502250 name=איילת שקד Ayelet Shaked username=Ayelet__Shaked>,
#  <User id=1082167187006242817 name=בני גנץ - Benny Gantz username=gantzbe>,
#  <User id=804535273 name=Ben Caspit בן כספית username=BenCaspit>,
#  <User id=32937363 name=Aviv Geffen username=avivgeffen>,
#  <User id=287610527 name=Merav Michaeli מרב מיכאלי username=MeravMichaeli>,
#  <User id=2438376520 name=דפנה ליאל username=DaphnaLiel>,
#  <User id=389214426 name=אהוד ברק username=barak_ehud>,
#  <User id=13197402 name=Naftali Bennett בנט username=naftalibennett>,
#  <User id=359299032 name=ליאור שליין username=LiorSchleien>,
#  <User id=216256233 name=אביגדור ליברמן username=AvigdorLiberman>,
#  <User id=57535118 name=Gideon Sa'ar | גדעון סער username=gidonsaar>,
#  <User id=2946300174 name=יאיר לפיד - Yair Lapid username=yairlapid>,
#  <User id=17061263 name=Benjamin Netanyahu username=netanyahu>,
#  <User id=1117811049305182211 name=אבישי בן חיים username=AvishayBenHaim>,
#  <User id=114894966 name=עמית סגל Amit Segal username=amit_segal>]

# %%
following_df = pd.DataFrame(following.data)
following_df
# Out:
#                      id                       name         username
# 0    750751206427860992             Marvel Studios    MarvelStudios
# 1              15687962       Marvel Entertainment           Marvel
# 2             710908592                 Matan Amir      matan_amirr
# 3   1481286902930190336   חדשות פוליטיות מלפני שנה    MilifneyShana
# 4   1103181775730327552                   קובי אוז          kobioz1
# 5    792405214762561537        Beitar Jerusalem FC         fcbeitar
# 6            3233484298              Year Progress    year_progress
# 7            2348783658    יצחק הרצוג Isaac Herzog     Isaac_Herzog
# 8   1091091503865384960       עומר בבאי omer babai        omerbabai
# 9   1040246229895204865                  ערוץ כנסת         KnessetT
# 10  1428289527186137094                    Yonatan         yonsha05
# 11           3085312765              Amir Hetsroni     AmirHetsroni
# 12             84180288      🫵🏻❤️Yoav Rabinovitz ⁦            yoavr
# 13            247253781                Reshef Shay         Rereshef
# 14            327746094            יבגני זרובינסקי            ivgiz
# 15  1273276672570253313                 yoram lass        LassYoram
# 16             37960888             Chaim Levinson    chaimlevinson
# 17            933990392                   ינון מגל       YinonMagal
# 18           3039661429                 רינה מצליח        RMatsliah
# 19           2426169308               Akiva Novick      akivanovick
# 20            917451193            אריה מכלוף דרעי        ariyederi
# 21            949502250    איילת שקד Ayelet Shaked   Ayelet__Shaked
# 22  1082167187006242817      בני גנץ - Benny Gantz          gantzbe
# 23            804535273        Ben Caspit בן כספית        BenCaspit
# 24             32937363                Aviv Geffen       avivgeffen
# 25            287610527  Merav Michaeli מרב מיכאלי    MeravMichaeli
# 26           2438376520                  דפנה ליאל       DaphnaLiel
# 27            389214426                   אהוד ברק       barak_ehud
# 28             13197402        Naftali Bennett בנט   naftalibennett
# 29            359299032                ליאור שליין     LiorSchleien
# 30            216256233             אביגדור ליברמן  AvigdorLiberman
# 31             57535118   Gideon Sa'ar | גדעון סער        gidonsaar
# 32           2946300174     יאיר לפיד - Yair Lapid        yairlapid
# 33             17061263         Benjamin Netanyahu        netanyahu
# 34  1117811049305182211              אבישי בן חיים   AvishayBenHaim
# 35            114894966        עמית סגל Amit Segal       amit_segal
